# %% [markdown]
# <a href="https://colab.research.google.com/github/dong-uk-kim97/code_study/blob/main/Back_3003.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 내가 작성한 정답

# %%
a,b,c,d,e,f = map(int, input().split())
print(1-a, 1-b, 2-c,2-d, 2-e, 8-f)
# Out:
# 2 1 2 1 2 1
# -1 0 0 1 0 7

# %% [markdown]
# 너무 어렵게 생각해서 정답인 리스트와 비교하려고 했는데 그럴 필요가 없다는 것을 깨닫고 각자 뺀 값을 비교하자는 생각을 했다. 그렇게 제출했더니 정답이 됐다. 근데 이 문제에 대한 정답은 맞지만 범용성이 부족하다는 것을 깨달았다. 좀 더 범용적인 코드를 짜야겠다는 생각을 했다.

# %% [markdown]
# # 오답노트

# %%
A = list(map(int,input().split())
B = [1,1,2,2,2,8]
print(B-A)
# Out:
#   File "<ipython-input-2-27451abd28ea>", line 2
#     B = [1,1,2,2,2,8]
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# 리스트를 연산한다는 시도 자체가 잘못됐다는 것을 깨달았다.
